# %% [markdown]
# # 1. Install Dependencies and Setup

# %%
import tensorflow as tf
import os
import cv2

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %% [markdown]
# # 2. Remove dodgy images

# %% [markdown]
# I'm sure taht this dataset is clear and not necessary to detect dodgy images, but it's standard practice if I use random pictures from web cause my Keras model works with 'jpeg','jpg', 'bmp', 'png' types of images.

# %%
image_path = os.path.join('data','fire_images','fire.1.png')
cv2.imread(image_path)
# Out:
# array([[[208, 209, 205],
#         [207, 208, 204],
#         [206, 207, 203],
#         ...,
#         [151, 166, 169],
#         [152, 167, 170],
#         [152, 167, 170]],
#
#        [[208, 209, 205],
#         [208, 209, 205],
#         [208, 209, 205],
#         ...,
#         [150, 165, 168],
#         [150, 165, 168],
#         [150, 165, 168]],
#
#        [[209, 210, 206],
#         [209, 210, 206],
#         [209, 210, 206],
#         ...,
#         [149, 163, 169],
#         [149, 163, 169],
#         [149, 163, 169]],
#
#        ...,
#
#        [[ 42,  55,  63],
#         [ 34,  46,  56],
#         [ 29,  43,  55],
#         ...,
#         [ 45,  85, 103],
#         [ 41,  73,  92],
#         [ 37,  64,  84]],
#
#        [[ 43,  52,  61],
#         [ 45,  55,  65],
#         [ 35,  47,  59],
#         ...,
#         [ 18,  54,  70],
#         [ 20,  48,  65],
#         [ 21,  45,  63]],
#
#        [[ 45,  52,  61],
#         [ 49,  55,  66],
#         [ 20,  28,  41],
#         ...,
#         [ 35,  56,  71],
#         [ 40,  53,  69],
#         [ 46,  54,  71]]], dtype=uint8)

# %%
import imghdr

# %%
data_dir = 'data'

# %%
image_exts = ['jpeg','jpg', 'bmp', 'png']

# %%
for image_class in os.listdir(data_dir): 
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))
            # os.remove(image_path)
# Out:
# Image not in ext list data/non_fire_images/non_fire.78.png
# Image not in ext list data/non_fire_images/non_fire.96.png
# Image not in ext list data/non_fire_images/non_fire.26.png
# Image not in ext list data/non_fire_images/non_fire.190.png
# Image not in ext list data/non_fire_images/non_fire.189.png
# Image not in ext list data/non_fire_images/non_fire.200.png
# Image not in ext list data/non_fire_images/non_fire.211.png
# Image not in ext list data/non_fire_images/non_fire.114.png
# Image not in ext list data/non_fire_images/non_fire.117.png
# Image not in ext list data/non_fire_images/non_fire.77.png
# Image not in ext list data/fire_images/fire.431.png
# Image not in ext list data/fire_images/fire.14.png
# Image not in ext list data/fire_images/fire.190.png
# Image not in ext list data/fire_images/fire.487.png
# Image not in ext list data/fire_images/fire.281.png
# Image not in ext list data/fire_images/fire.77.png
# Image not in ext list data/fire_images/fire.292.png
# Image not in ext list data/fire_images/fire.260.png
# Image not in ext list data/fire_images/fire.307.png
# Image not in ext list data/fire_images/fire.489.png
# Issue with image data/fire_images/.ipynb_checkpoints
# Image not in ext list data/fire_images/fire.32.png
# Image not in ext list data/fire_images/fire.361.png

# %% [markdown]
# # 3. Load Data

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = tf.keras.utils.image_dataset_from_directory('data')
# Out:
# Found 981 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# # 4. Scale Data

# %%
data = data.map(lambda x,y: (x/255, y))

# %%
batch = data.as_numpy_iterator().next()
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img)
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# # 5. Split Data

# %%
print('Total number of batches: {}'.format(len(data)))
# Out:
# Total number of batches: 31

# %%
train_size = int(len(data)*.7) + 1
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)

# %%
print('train set: {} batches'.format(train_size))
print('val set: {} batches'.format(val_size))
print('test set: {} batches'.format(test_size))
# Out:
# train set: 22 batches
# val set: 6 batches
# test set: 3 batches

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# # 6. Build Deep Learning Model

# %%
train
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 16)        0
#  g2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3696625 (14.10 MB)
# Trainable params: 3696625 (14.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # 7. Train

# %%
logdir='train_logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 22/22 [==============================] - 14s 566ms/step - loss: 0.5457 - accuracy: 0.7543 - val_loss: 0.1993 - val_accuracy: 0.9115
# Epoch 2/20
# 22/22 [==============================] - 14s 568ms/step - loss: 0.1680 - accuracy: 0.9418 - val_loss: 0.1011 - val_accuracy: 0.9635
# Epoch 3/20
# 22/22 [==============================] - 14s 565ms/step - loss: 0.1345 - accuracy: 0.9460 - val_loss: 0.1540 - val_accuracy: 0.9271
# Epoch 4/20
# 22/22 [==============================] - 14s 573ms/step - loss: 0.1388 - accuracy: 0.9474 - val_loss: 0.1077 - val_accuracy: 0.9740
# Epoch 5/20
# 22/22 [==============================] - 14s 571ms/step - loss: 0.1011 - accuracy: 0.9560 - val_loss: 0.0678 - val_accuracy: 0.9740
# Epoch 6/20
# 22/22 [==============================] - 14s 565ms/step - loss: 0.1110 - accuracy: 0.9702 - val_loss: 0.0736 - val_accuracy: 0.9740
# Epoch 7/20
# 22/22 [==============================] - 14s 565ms/step - loss: 0.0783 - accuracy: 0.9744 - val_loss: 0.2075 - val_accuracy: 0.9323
# Epoch 8/20
# 22/22 [==============================] - 14s 573ms/step - loss: 0.0624 - accuracy: 0.9787 - val_loss: 0.1295 - val_accuracy: 0.9583
# Epoch 9/20
# 22/22 [==============================] - 14s 580ms/step - loss: 0.0533 - accuracy: 0.9787 - val_loss: 0.0793 - val_accuracy: 0.9740
# Epoch 10/20
# 22/22 [==============================] - 14s 574ms/step - loss: 0.0401 - accuracy: 0.9830 - val_loss: 0.0575 - val_accuracy: 0.9844
# Epoch 11/20
# 22/22 [==============================] - 14s 572ms/step - loss: 0.0712 - accuracy: 0.9759 - val_loss: 0.0810 - val_accuracy: 0.9740
# Epoch 12/20
# 22/22 [==============================] - 14s 577ms/step - loss: 0.0378 - accuracy: 0.9872 - val_loss: 0.0709 - val_accuracy: 0.9792
# Epoch 13/20
# 22/22 [==============================] - 14s 567ms/step - loss: 0.0247 - accuracy: 0.9929 - val_loss: 0.0663 - val_accuracy: 0.9792
# Epoch 14/20
# 22/22 [==============================] - 14s 578ms/step - loss: 0.0178 - accuracy: 0.9943 - val_loss: 0.0659 - val_accuracy: 0.9792
# Epoch 15/20
# 22/22 [==============================] - 14s 576ms/step - loss: 0.0239 - accuracy: 0.9957 - val_loss: 0.0439 - val_accuracy: 0.9948
# Epoch 16/20
# 22/22 [==============================] - 14s 580ms/step - loss: 0.0201 - accuracy: 0.9972 - val_loss: 0.0422 - val_accuracy: 0.9948
# Epoch 17/20
# 22/22 [==============================] - 14s 569ms/step - loss: 0.0250 - accuracy: 0.9915 - val_loss: 0.0503 - val_accuracy: 0.9844
# Epoch 18/20
# 22/22 [==============================] - 14s 574ms/step - loss: 0.0540 - accuracy: 0.9744 - val_loss: 0.0648 - val_accuracy: 0.9792
# Epoch 19/20
# 22/22 [==============================] - 14s 571ms/step - loss: 0.0415 - accuracy: 0.9901 - val_loss: 0.0428 - val_accuracy: 0.9844
# Epoch 20/20
# 22/22 [==============================] - 14s 578ms/step - loss: 0.0358 - accuracy: 0.9858 - val_loss: 0.0204 - val_accuracy: 1.0000

# %% [markdown]
# # 8. Plot Performance

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # 9. Evaluate

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
# Out:
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 70ms/step

# %%
print('precision: {}'.format(pre.result()))
print('recall: {}'.format(re.result()))
print('accuracy: {}'.format(acc.result()))
# Out:
# precision: 1.0
# recall: 1.0
# accuracy: 1.0

# %% [markdown]
# # 10. Test

# %%
img = cv2.imread('Campfire-Safety-4-of-4-scaled.png')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 [==============================] - 0s 18ms/step

# %%
yhat
# Out:
# array([[0.9997229]], dtype=float32)

# %%
if yhat > 0.5: 
    print(f'Predicted class is FIRE')
else:
    print(f'Predicted class is NON-FIRE')
# Out:
# Predicted class is FIRE

# %% [markdown]
# # 11. Save the Model

# %%
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('models','fire_classifier.h5'))
# Out:
# /Users/aweeu/anaconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
new_model = load_model('models/fire_classifier.h5')

# %%
new_model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 [==============================] - 0s 52ms/step
# array([[0.9997229]], dtype=float32)
